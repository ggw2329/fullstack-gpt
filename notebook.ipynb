# %%
from langchain.chat_models import ChatOpenAI

chat = ChatOpenAI(
    temperature=0.5
)
# Out:
# 'Eight planets in our Solar System.\n\nNote: Pluto was reclassified as a dwarf planet in 2006. There are also thousands of confirmed exoplanets orbiting other stars outside our Solar System. If you’d like, I can list the eight planets or tell you about some nearby exoplanets.'

# %%
from langchain.schema import HumanMessage, AIMessagem, SystemMessage

messages = [
    SystemMessage(
        content="You are a geography expert. And you"
    )
]
